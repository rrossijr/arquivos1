# %% [markdown]
# <a href="https://colab.research.google.com/github/rrossijr/arquivos1/blob/main/Abir_CSV_read_CSV_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6d6871cb-641d-4c05-92a3-c7022e3a7067" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6d6871cb-641d-4c05-92a3-c7022e3a7067">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['Admission_Predict.csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
df2.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df2.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
N_df = df2.rename(columns={'LOR ':'Letter of Recom'})
N_df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  \
# 0           1        337          118                  4  4.5
# 1           2        324          107                  4  4.0
# 2           3        316          104                  3  3.0
# 3           4        322          110                  3  3.5
# 4           5        314          103                  2  2.0
#
#    Letter of Recom  CGPA  Research  Chance of Admit
# 0              4.5  9.65         1              0.92
# 1              4.5  8.87         1              0.76
# 2              3.5  8.00         1              0.72
# 3              2.5  8.67         1              0.80
# 4              3.0  8.21         0              0.65

# %%
cols = list(df2.columns)
print(cols)
cols = [x.lower().strip() for x in cols]
print(cols)
df2.columns = cols
# Out:
# ['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA', 'Research', 'Chance of Admit ']
# ['serial no.', 'gre score', 'toefl score', 'university rating', 'sop', 'lor', 'cgpa', 'research', 'chance of admit']

# %%
admit_mask = df2['chance of admit']>0.7
admit_mask
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 395     True
# 396     True
# 397     True
# 398    False
# 399     True
# Name: chance of admit, Length: 400, dtype: bool

# %%
df2.where(admit_mask).dropna().head()
# Out:
#    serial no.  gre score  toefl score  university rating  sop  lor  cgpa  \
# 0         1.0      337.0        118.0                4.0  4.5  4.5  9.65
# 1         2.0      324.0        107.0                4.0  4.0  4.5  8.87
# 2         3.0      316.0        104.0                3.0  3.0  3.5  8.00
# 3         4.0      322.0        110.0                3.0  3.5  2.5  8.67
# 5         6.0      330.0        115.0                5.0  4.5  3.0  9.34
#
#    research  chance of admit
# 0       1.0             0.92
# 1       1.0             0.76
# 2       1.0             0.72
# 3       1.0             0.80
# 5       1.0             0.90

# %%
(df2['chance of admit'] > 0.7) & (df2['chance of admit'] < 0.9 )
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 395     True
# 396     True
# 397    False
# 398    False
# 399    False
# Name: chance of admit, Length: 400, dtype: bool

# %%
df2.set_index('serial no.')
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# serial no.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
# ...               ...          ...                ...  ...  ...   ...
# 396               324          110                  3  3.5  3.5  9.04
# 397               325          107                  3  3.0  3.5  9.11
# 398               330          116                  4  5.0  4.5  9.45
# 399               312          103                  3  3.5  4.0  8.78
# 400               333          117                  4  5.0  4.0  9.66
#
#             research  chance of admit
# serial no.
# 1                  1             0.92
# ...
